# %%
import boto3
import pandas as pd
import numpy as np
import re
from io import StringIO
import datetime
from dotenv import load_dotenv

# %%
# Nazwa bucketu S3
BUCKET_NAME = "zadmod-9"

# Wczytanie zmiennych środowiskowych
load_dotenv()

# Inicjalizacja klienta S3
s3 = boto3.client("s3")

def load_data_from_s3(file_key):
    """Wczytuje dane z S3 do DataFrame."""
    obj = s3.get_object(Bucket=BUCKET_NAME, Key=file_key)
    csv_data = obj['Body'].read().decode('utf-8')
    df = pd.read_csv(StringIO(csv_data), sep=";")
    return df

# Wczytaj dane dla 2023 i 2024
wroclaw_2023_df = load_data_from_s3("Dane_mod9/halfmarathon_wroclaw_2023__final.csv")
wroclaw_2024_df = load_data_from_s3("Dane_mod9/halfmarathon_wroclaw_2024__final.csv")

# %%
# I. KONWERSJA CZASU
def convert_time_to_seconds(time):
    if pd.isnull(time) or time in ['DNS', 'DNF']: #DID NOT START / DID NOT FINISH
        return None
    time = time.split(':')
    return int(time[0]) * 3600 + int(time[1]) * 60 + int(time[2])

# %%
import pandas as pd

def get_cleaned_dataframe(df_2023: pd.DataFrame, df_2024: pd.DataFrame) -> pd.DataFrame:
    df_combined = pd.concat([df_2023, df_2024], ignore_index=True)  # Łączenie danych z obu lat
    df_model = df_combined[df_combined['Miejsce'].notnull()].copy() # Usuwanie wierszy z brakującymi miejscami 

    # Usuwanie zbędnych kolumn
    columns_to_drop = ['Drużyna', 'Miasto'] # Wybrane kolumny do usunięcia
    df_model.drop(columns=columns_to_drop, inplace=True)

    return df_model

# %%
cleaned_df = get_cleaned_dataframe(wroclaw_2023_df, wroclaw_2024_df)
missing_values_count = cleaned_df.isna().sum().reset_index(name='ilość')

# %%
cleaned_df.isna().sum().reset_index(name='ilość')
# Out:
#                         index  ilość
# 0                     Miejsce      0
# 1              Numer startowy      0
# 2                        Imię      0
# 3                    Nazwisko      0
# 4                        Kraj      0
# 5                        Płeć      0
# 6                Płeć Miejsce      0
# 7           Kategoria wiekowa     20
# 8   Kategoria wiekowa Miejsce     20
# 9                     Rocznik    485
# 10                  5 km Czas     39
# 11          5 km Miejsce Open     39
# 12                 5 km Tempo     39
# 13                 10 km Czas     23
# 14         10 km Miejsce Open     23
# 15                10 km Tempo     55
# 16                 15 km Czas     22
# 17         15 km Miejsce Open     22
# 18                15 km Tempo     37
# 19                 20 km Czas     11
# 20         20 km Miejsce Open     11
# 21                20 km Tempo     28
# 22           Tempo Stabilność     73
# 23                       Czas      0
# 24                      Tempo      0

# %%
def impute_rocznik_from_category(df: pd.DataFrame) -> pd.DataFrame:
    """
    Uzupełnia brakujące wartości w kolumnie 'Rocznik'
    medianą dla każdej 'Kategorii wiekowej' i dodaje kolumnę 'Wiek'.
    """
    if 'Rocznik' not in df.columns or 'Kategoria wiekowa' not in df.columns:
        return df

    df_result = df.copy()

    # Oblicz medianę 'Rocznik' dla każdej kategorii wiekowej
    median_map = df_result.groupby('Kategoria wiekowa')['Rocznik'].transform('median').round(0).astype('Int64')

    # Uzupełnij brakujące 'Rocznik' medianą odpowiedniej kategorii
    df_result['Rocznik'] = df_result['Rocznik'].fillna(median_map)

    # Dodaj kolumnę 'Wiek'
    df_result['Wiek'] = 2024 - df_result['Rocznik']

    # Usuń kolumnę 'Rocznik'
    df_result = df_result.drop(columns=['Rocznik'])

    # Wyświetl liczby brakujących przed i po
    print(f"Brakujące wartości w 'Rocznik' przed imputacją: {(df['Rocznik'].isnull().sum())}")
    print(f"Brakujące wartości w 'Rocznik' po imputacji: {(df_result['Wiek'].isnull().sum())}")

    return df_result

# %%
cleaned_df = get_cleaned_dataframe(wroclaw_2023_df, wroclaw_2024_df)
cleaned_df = impute_rocznik_from_category(cleaned_df)
cleaned_df
# Out:
# Brakujące wartości w 'Rocznik' przed imputacją: 485
# Brakujące wartości w 'Rocznik' po imputacji: 0
#        Miejsce  Numer startowy           Imię       Nazwisko Kraj Płeć  \
# 0          1.0            1787         TOMASZ         GRYCKO  POL    M
# 1          2.0               3      ARKADIUSZ  GARDZIELEWSKI  POL    M
# 2          3.0            3832      KRZYSZTOF          HADAS  POL    M
# 3          4.0             416         DAMIAN         DYDUCH  POL    M
# 4          5.0            8476          KAMIL      MAŃKOWSKI  POL    M
# ...        ...             ...            ...            ...  ...  ...
# 19245  10298.0             898  EWA KATARZYNA      KASIERSKA  POL    K
# 19246  10299.0           10456      MAGDALENA         PRYNDA  POL    K
# 19247  10300.0           11311         HELENA         KOLANY  POL    K
# 19248  10301.0            8404         JOANNA       KAJDANEK  POL    K
# 19249  10302.0           11155      Anonimowy       ZAWODNIK  POL    M
#
#        Płeć Miejsce Kategoria wiekowa  Kategoria wiekowa Miejsce 5 km Czas  \
# 0               1.0               M30                        1.0  00:14:37
# 1               2.0               M30                        2.0  00:14:48
# 2               3.0               M20                        1.0  00:15:46
# 3               4.0               M30                        3.0  00:16:11
# 4               5.0               M20                        2.0  00:16:12
# ...             ...               ...                        ...       ...
# 19245        3059.0               K70                        6.0  00:43:30
# 19246        3060.0               K40                     1030.0  00:42:06
# 19247        3061.0               K60                       48.0  00:49:20
# 19248        3062.0               K40                     1031.0  00:46:48
# 19249        7240.0               M40                     2388.0  00:50:14
#
#        ...  15 km Czas  15 km Miejsce Open 15 km Tempo  20 km Czas  \
# 0      ...    00:44:47                 1.0    3.106667    01:01:43
# 1      ...    00:45:26                 2.0    3.143333    01:03:08
# 2      ...    00:47:34                 3.0    3.236667    01:05:09
# 3      ...    00:48:49                 5.0    3.330000    01:06:54
# 4      ...    00:49:31                 7.0    3.386667    01:07:27
# ...    ...         ...                 ...         ...         ...
# 19245  ...         NaN                 NaN         NaN         NaN
# 19246  ...    02:15:28             10301.0    9.580000    03:10:19
# 19247  ...    02:23:22             10303.0    9.010000    03:11:34
# 19248  ...    02:26:03             10304.0    9.980000    03:17:25
# 19249  ...    02:34:09             10305.0   10.136667    03:21:22
#
#        20 km Miejsce Open 20 km Tempo  Tempo Stabilność      Czas      Tempo  \
# 0                     1.0    3.386667          0.031400  01:04:59   3.080509
# 1                     2.0    3.540000          0.038000  01:06:23   3.146875
# 2                     3.0    3.516667          0.024067  01:08:24   3.242475
# 3                     4.0    3.616667          0.025467  01:10:16   3.330963
# 4                     5.0    3.586667          0.023000  01:10:27   3.339654
# ...                   ...         ...               ...       ...        ...
# 19245                 NaN         NaN               NaN  03:19:47   9.470649
# 19246             10303.0   10.970000          0.162733  03:21:08   9.534645
# 19247             10304.0    9.640000         -0.029333  03:22:18   9.589950
# 19248             10305.0   10.273333          0.057000  03:28:32   9.885439
# 19249             10306.0    9.443333         -0.046400  03:32:34  10.076637
#
#        Wiek
# 0      32.0
# 1      38.0
# 2      28.0
# 3      36.0
# 4      29.0
# ...     ...
# 19245  76.0
# 19246  46.0
# 19247  69.0
# 19248  43.0
# 19249  44.0
#
# [18450 rows x 25 columns]

# %%
# Zmieniasz kolumny czasu w cleaned_df
time_columns = ['5 km Czas', '10 km Czas', '15 km Czas', '20 km Czas', 'Czas']
cleaned_df[time_columns] = cleaned_df[time_columns].applymap(convert_time_to_seconds)

# Teraz wyświetlasz
print(cleaned_df)
# Out:
#        Miejsce  Numer startowy           Imię       Nazwisko Kraj Płeć  \
# 0          1.0            1787         TOMASZ         GRYCKO  POL    M
# 1          2.0               3      ARKADIUSZ  GARDZIELEWSKI  POL    M
# 2          3.0            3832      KRZYSZTOF          HADAS  POL    M
# 3          4.0             416         DAMIAN         DYDUCH  POL    M
# 4          5.0            8476          KAMIL      MAŃKOWSKI  POL    M
# ...        ...             ...            ...            ...  ...  ...
# 19245  10298.0             898  EWA KATARZYNA      KASIERSKA  POL    K
# 19246  10299.0           10456      MAGDALENA         PRYNDA  POL    K
# 19247  10300.0           11311         HELENA         KOLANY  POL    K
# 19248  10301.0            8404         JOANNA       KAJDANEK  POL    K
# 19249  10302.0           11155      Anonimowy       ZAWODNIK  POL    M
#
#        Płeć Miejsce Kategoria wiekowa  Kategoria wiekowa Miejsce  5 km Czas  \
# 0               1.0               M30                        1.0      877.0
# 1               2.0               M30                        2.0      888.0
# 2               3.0               M20                        1.0      946.0
# 3               4.0               M30                        3.0      971.0
# 4               5.0               M20                        2.0      972.0
# ...             ...               ...                        ...        ...
# 19245        3059.0               K70                        6.0     2610.0
# 19246        3060.0               K40                     1030.0     2526.0
# 19247        3061.0               K60                       48.0     2960.0
# 19248        3062.0               K40                     1031.0     2808.0
# 19249        7240.0               M40                     2388.0     3014.0
#
#        ...  15 km Czas  15 km Miejsce Open  15 km Tempo  20 km Czas  \
# 0      ...      2687.0                 1.0     3.106667      3703.0
# 1      ...      2726.0                 2.0     3.143333      3788.0
# 2      ...      2854.0                 3.0     3.236667      3909.0
# 3      ...      2929.0                 5.0     3.330000      4014.0
# 4      ...      2971.0                 7.0     3.386667      4047.0
# ...    ...         ...                 ...          ...         ...
# 19245  ...         NaN                 NaN          NaN         NaN
# 19246  ...      8128.0             10301.0     9.580000     11419.0
# 19247  ...      8602.0             10303.0     9.010000     11494.0
# 19248  ...      8763.0             10304.0     9.980000     11845.0
# 19249  ...      9249.0             10305.0    10.136667     12082.0
#
#        20 km Miejsce Open  20 km Tempo  Tempo Stabilność   Czas      Tempo  \
# 0                     1.0     3.386667          0.031400   3899   3.080509
# 1                     2.0     3.540000          0.038000   3983   3.146875
# 2                     3.0     3.516667          0.024067   4104   3.242475
# 3                     4.0     3.616667          0.025467   4216   3.330963
# 4                     5.0     3.586667          0.023000   4227   3.339654
# ...                   ...          ...               ...    ...        ...
# 19245                 NaN          NaN               NaN  11987   9.470649
# 19246             10303.0    10.970000          0.162733  12068   9.534645
# 19247             10304.0     9.640000         -0.029333  12138   9.589950
# 19248             10305.0    10.273333          0.057000  12512   9.885439
# 19249             10306.0     9.443333         -0.046400  12754  10.076637
#
#        Wiek
# 0      32.0
# 1      38.0
# 2      28.0
# 3      36.0
# 4      29.0
# ...     ...
# 19245  76.0
# 19246  46.0
# 19247  69.0
# 19248  43.0
# 19249  44.0
#
# [18450 rows x 25 columns]
# C:\Users\Michal\AppData\Local\Temp\ipykernel_18976\3704622056.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   cleaned_df[time_columns] = cleaned_df[time_columns].applymap(convert_time_to_seconds)

# %%
cleaned_df.dropna(subset=time_columns, inplace=True)

# %%
cleaned_df.isna().sum().reset_index(name='ilość')
# Out:
#                         index  ilość
# 0                     Miejsce      0
# 1              Numer startowy      0
# 2                        Imię      0
# 3                    Nazwisko      0
# 4                        Kraj      0
# 5                        Płeć      0
# 6                Płeć Miejsce      0
# 7           Kategoria wiekowa     17
# 8   Kategoria wiekowa Miejsce     17
# 9                   5 km Czas      0
# 10          5 km Miejsce Open      0
# 11                 5 km Tempo      0
# 12                 10 km Czas      0
# 13         10 km Miejsce Open      0
# 14                10 km Tempo      0
# 15                 15 km Czas      0
# 16         15 km Miejsce Open      0
# 17                15 km Tempo      0
# 18                 20 km Czas      0
# 19         20 km Miejsce Open      0
# 20                20 km Tempo      0
# 21           Tempo Stabilność      0
# 22                       Czas      0
# 23                      Tempo      0
# 24                       Wiek      0

# %%
# Funkcja do policzenia liczby outliers w serii
def count_outliers(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = series[(series < lower_bound) | (series > upper_bound)]
    return len(outliers)

# Funkcja do usuwania outliers z DataFrame w podanej kolumnie
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)].copy()

# Lista kolumn, z których chcesz usunąć outliers
columns_to_clean = [
    'Tempo', 
    '5 km Czas', '10 km Czas', '15 km Czas', '20 km Czas', 'Czas',
    '5 km Tempo', '10 km Tempo', '15 km Tempo', '20 km Tempo'
]

# Liczba outliers przed usunięciem
outliers_counts = {}
for col in columns_to_clean:
    if col in cleaned_df.columns and pd.api.types.is_numeric_dtype(cleaned_df[col]):
        outliers_counts[col] = count_outliers(cleaned_df[col])

print("--- Liczba outliers przed usunięciem ---")
for col, count in outliers_counts.items():
    print(f"{col}: {count}")

# Usuwanie outliers kaskadowo
for col in columns_to_clean:
    if col in cleaned_df.columns and pd.api.types.is_numeric_dtype(cleaned_df[col]):
        cleaned_df = remove_outliers(cleaned_df, col)

print(f"\nLiczba rekordów po usunięciu outliers: {len(cleaned_df)}")
# Out:
# --- Liczba outliers przed usunięciem ---
# Tempo: 222
# 5 km Czas: 135
# 10 km Czas: 178
# 15 km Czas: 203
# 20 km Czas: 225
# Czas: 222
# 5 km Tempo: 135
# 10 km Tempo: 256
# 15 km Tempo: 294
# 20 km Tempo: 408
#
# Liczba rekordów po usunięciu outliers: 17626

# %%
cleaned_df
# Out:
#        Miejsce  Numer startowy        Imię     Nazwisko Kraj Płeć  \
# 8          9.0            5657     CYPRIAN      GRZELKA  POL    M
# 10        11.0            7270     MATEUSZ   POŁCZYŃSKI  POL    M
# 11        12.0            4367      MACIEJ       KARDAS  POL    M
# 12        13.0             923   SEBASTIAN       CIEŚLA  POL    M
# 13        14.0            4565    WOJCIECH   DURCZYŃSKI  POL    M
# ...        ...             ...         ...          ...  ...  ...
# 18999  10052.0            3158  PRZEMYSŁAW     STELMACH  POL    M
# 19000  10053.0            1987       PAWEŁ      NOWICKI  POL    M
# 19003  10056.0           11600   KATARZYNA    KOPROWSKA  POL    K
# 19008  10061.0            9801       IWONA     HOŁOWACZ  POL    K
# 19064  10117.0            6660     ANDRZEJ  GRZEŚKOWIAK  POL    M
#
#        Płeć Miejsce Kategoria wiekowa  Kategoria wiekowa Miejsce  5 km Czas  \
# 8               9.0               M20                        4.0     1030.0
# 10             11.0               M20                        5.0     1029.0
# 11             12.0               M30                        6.0     1035.0
# 12             13.0               M20                        6.0     1035.0
# 13             14.0               M30                        7.0     1036.0
# ...             ...               ...                        ...        ...
# 18999        7129.0               M40                     2360.0     2219.0
# 19000        7130.0               M40                     2361.0     2220.0
# 19003        2925.0               K30                     1013.0     2289.0
# 19008        2928.0               K40                      990.0     2146.0
# 19064        7162.0               M70                       38.0     2238.0
#
#        ...  15 km Czas  15 km Miejsce Open  15 km Tempo  20 km Czas  \
# 8      ...      3131.0                12.0     3.560000      4263.0
# 10     ...      3131.0                13.0     3.560000      4282.0
# 11     ...      3133.0                16.0     3.566667      4284.0
# 12     ...      3133.0                14.0     3.566667      4290.0
# 13     ...      3134.0                17.0     3.566667      4292.0
# ...    ...         ...                 ...          ...         ...
# 18999  ...      6975.0             10070.0     8.166667      9593.0
# 19000  ...      6981.0             10076.0     8.186667      9592.0
# 19003  ...      6958.0             10062.0     8.040000      9593.0
# 19008  ...      6877.0             10029.0     8.243333      9594.0
# 19064  ...      7035.0             10099.0     8.326667      9751.0
#
#        20 km Miejsce Open  20 km Tempo  Tempo Stabilność   Czas     Tempo  \
# 8                    10.0     3.773333          0.022733   4456  3.520581
# 10                   11.0     3.836667          0.026667   4483  3.541914
# 11                   12.0     3.836667          0.026000   4490  3.547444
# 12                   13.0     3.856667          0.027200   4496  3.552185
# 13                   14.0     3.860000          0.027200   4505  3.559295
# ...                   ...          ...               ...    ...       ...
# 18999             10060.0     8.726667          0.089400  10194  8.054041
# 19000             10057.0     8.703333          0.088267  10194  8.054041
# 19003             10059.0     8.783333          0.079533  10206  8.063522
# 19008             10062.0     9.056667          0.128533  10218  8.073003
# 19064             10117.0     9.053333          0.108867  10382  8.202576
#
#        Wiek
# 8      23.0
# 10     27.0
# 11     32.0
# 12     28.0
# 13     33.0
# ...     ...
# 18999  41.0
# 19000  41.0
# 19003  38.0
# 19008  49.0
# 19064  70.0
#
# [17626 rows x 25 columns]

# %%
from pycaret.regression import setup, compare_models, finalize_model, plot_model, save_model, predict_model

# %%
# Eksperymwnt na całymm zbiorze z zmienną docelową 'Czas'
exp = setup(
    data=cleaned_df,
    target='Czas', # Czas ukończenia biegu w sekundach jako zmienna docelowa
    session_id=123,
    verbose=True,
    
)
# exp.dataset_transformed.sample(10)
# Out:
# <style type="text/css">
# #T_633ce_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_633ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_633ce_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_633ce_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_633ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_633ce_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_633ce_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_633ce_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_633ce_row1_col1" class="data row1 col1" >Czas</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_633ce_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_633ce_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_633ce_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_633ce_row3_col1" class="data row3 col1" >(17626, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_633ce_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_633ce_row4_col1" class="data row4 col1" >(17626, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_633ce_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_633ce_row5_col1" class="data row5 col1" >(12338, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_633ce_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_633ce_row6_col1" class="data row6 col1" >(5288, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_633ce_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_633ce_row7_col1" class="data row7 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_633ce_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_633ce_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_633ce_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_633ce_row9_col1" class="data row9 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_633ce_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_633ce_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_633ce_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_633ce_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_633ce_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_633ce_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_633ce_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_633ce_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_633ce_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_633ce_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_633ce_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_633ce_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_633ce_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_633ce_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_633ce_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_633ce_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_633ce_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_633ce_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_633ce_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_633ce_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_633ce_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_633ce_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_633ce_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_633ce_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_633ce_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_633ce_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_633ce_row22_col1" class="data row22 col1" >0504</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Trenuje i ocenia wszystkie modele za pomocą walidacji krzyżowej (domyślnie 10-krotnej).
best_model_v1 = exp.compare_models(sort='MAE')
# Out:
# <style type="text/css">
# #T_fe153 th {
#   text-align: left;
# }
# #T_fe153_row0_col0, #T_fe153_row1_col0, #T_fe153_row1_col1, #T_fe153_row1_col2, #T_fe153_row1_col3, #T_fe153_row1_col5, #T_fe153_row2_col0, #T_fe153_row2_col1, #T_fe153_row2_col2, #T_fe153_row2_col3, #T_fe153_row2_col5, #T_fe153_row3_col0, #T_fe153_row3_col1, #T_fe153_row3_col2, #T_fe153_row3_col3, #T_fe153_row3_col4, #T_fe153_row3_col5, #T_fe153_row3_col6, #T_fe153_row4_col0, #T_fe153_row4_col1, #T_fe153_row4_col2, #T_fe153_row4_col3, #T_fe153_row4_col4, #T_fe153_row4_col5, #T_fe153_row4_col6, #T_fe153_row5_col0, #T_fe153_row5_col1, #T_fe153_row5_col2, #T_fe153_row5_col3, #T_fe153_row5_col4, #T_fe153_row5_col5, #T_fe153_row5_col6, #T_fe153_row6_col0, #T_fe153_row6_col1, #T_fe153_row6_col2, #T_fe153_row6_col3, #T_fe153_row6_col4, #T_fe153_row6_col5, #T_fe153_row6_col6, #T_fe153_row7_col0, #T_fe153_row7_col1, #T_fe153_row7_col2, #T_fe153_row7_col3, #T_fe153_row7_col4, #T_fe153_row7_col5, #T_fe153_row7_col6, #T_fe153_row8_col0, #T_fe153_row8_col1, #T_fe153_row8_col2, #T_fe153_row8_col3, #T_fe153_row8_col4, #T_fe153_row8_col5, #T_fe153_row8_col6 {
#   text-align: left;
# }
# #T_fe153_row0_col1, #T_fe153_row0_col2, #T_fe153_row0_col3, #T_fe153_row0_col4, #T_fe153_row0_col5, #T_fe153_row0_col6, #T_fe153_row1_col4, #T_fe153_row1_col6, #T_fe153_row2_col4, #T_fe153_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fe153_row0_col7, #T_fe153_row1_col7, #T_fe153_row2_col7, #T_fe153_row3_col7, #T_fe153_row4_col7, #T_fe153_row5_col7, #T_fe153_row6_col7, #T_fe153_row7_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fe153_row8_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fe153">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe153_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fe153_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fe153_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fe153_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fe153_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fe153_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fe153_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fe153_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe153_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_fe153_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_fe153_row0_col1" class="data row0 col1" >0.4527</td>
#       <td id="T_fe153_row0_col2" class="data row0 col2" >5.6846</td>
#       <td id="T_fe153_row0_col3" class="data row0 col3" >1.8766</td>
#       <td id="T_fe153_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_fe153_row0_col5" class="data row0 col5" >0.0003</td>
#       <td id="T_fe153_row0_col6" class="data row0 col6" >0.0001</td>
#       <td id="T_fe153_row0_col7" class="data row0 col7" >1.6840</td>
#     </tr>
#     <tr>
#       <th id="T_fe153_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_fe153_row1_col0" class="data row1 col0" >Decision Tree Regressor</td>
#       <td id="T_fe153_row1_col1" class="data row1 col1" >0.7493</td>
#       <td id="T_fe153_row1_col2" class="data row1 col2" >8.8799</td>
#       <td id="T_fe153_row1_col3" class="data row1 col3" >2.7267</td>
#       <td id="T_fe153_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_fe153_row1_col5" class="data row1 col5" >0.0004</td>
#       <td id="T_fe153_row1_col6" class="data row1 col6" >0.0001</td>
#       <td id="T_fe153_row1_col7" class="data row1 col7" >0.0850</td>
#     </tr>
#     <tr>
#       <th id="T_fe153_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_fe153_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_fe153_row2_col1" class="data row2 col1" >0.9715</td>
#       <td id="T_fe153_row2_col2" class="data row2 col2" >16.2555</td>
#       <td id="T_fe153_row2_col3" class="data row2 col3" >3.6094</td>
#       <td id="T_fe153_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_fe153_row2_col5" class="data row2 col5" >0.0005</td>
#       <td id="T_fe153_row2_col6" class="data row2 col6" >0.0001</td>
#       <td id="T_fe153_row2_col7" class="data row2 col7" >0.7880</td>
#     </tr>
#     <tr>
#       <th id="T_fe153_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_fe153_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_fe153_row3_col1" class="data row3 col1" >4.9186</td>
#       <td id="T_fe153_row3_col2" class="data row3 col2" >71.5053</td>
#       <td id="T_fe153_row3_col3" class="data row3 col3" >8.3454</td>
#       <td id="T_fe153_row3_col4" class="data row3 col4" >0.9999</td>
#       <td id="T_fe153_row3_col5" class="data row3 col5" >0.0012</td>
#       <td id="T_fe153_row3_col6" class="data row3 col6" >0.0007</td>
#       <td id="T_fe153_row3_col7" class="data row3 col7" >0.2070</td>
#     </tr>
#     <tr>
#       <th id="T_fe153_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_fe153_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_fe153_row4_col1" class="data row4 col1" >7.7955</td>
#       <td id="T_fe153_row4_col2" class="data row4 col2" >110.0103</td>
#       <td id="T_fe153_row4_col3" class="data row4 col3" >10.4792</td>
#       <td id="T_fe153_row4_col4" class="data row4 col4" >0.9999</td>
#       <td id="T_fe153_row4_col5" class="data row4 col5" >0.0015</td>
#       <td id="T_fe153_row4_col6" class="data row4 col6" >0.0011</td>
#       <td id="T_fe153_row4_col7" class="data row4 col7" >0.7800</td>
#     </tr>
#     <tr>
#       <th id="T_fe153_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_fe153_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_fe153_row5_col1" class="data row5 col1" >23.5257</td>
#       <td id="T_fe153_row5_col2" class="data row5 col2" >1171.9758</td>
#       <td id="T_fe153_row5_col3" class="data row5 col3" >34.1889</td>
#       <td id="T_fe153_row5_col4" class="data row5 col4" >0.9990</td>
#       <td id="T_fe153_row5_col5" class="data row5 col5" >0.0043</td>
#       <td id="T_fe153_row5_col6" class="data row5 col6" >0.0031</td>
#       <td id="T_fe153_row5_col7" class="data row5 col7" >0.4080</td>
#     </tr>
#     <tr>
#       <th id="T_fe153_level0_row6" class="row_heading level0 row6" >par</th>
#       <td id="T_fe153_row6_col0" class="data row6 col0" >Passive Aggressive Regressor</td>
#       <td id="T_fe153_row6_col1" class="data row6 col1" >28.7686</td>
#       <td id="T_fe153_row6_col2" class="data row6 col2" >1426.1454</td>
#       <td id="T_fe153_row6_col3" class="data row6 col3" >37.5555</td>
#       <td id="T_fe153_row6_col4" class="data row6 col4" >0.9988</td>
#       <td id="T_fe153_row6_col5" class="data row6 col5" >0.0049</td>
#       <td id="T_fe153_row6_col6" class="data row6 col6" >0.0039</td>
#       <td id="T_fe153_row6_col7" class="data row6 col7" >0.5310</td>
#     </tr>
#     <tr>
#       <th id="T_fe153_level0_row7" class="row_heading level0 row7" >ada</th>
#       <td id="T_fe153_row7_col0" class="data row7 col0" >AdaBoost Regressor</td>
#       <td id="T_fe153_row7_col1" class="data row7 col1" >53.8290</td>
#       <td id="T_fe153_row7_col2" class="data row7 col2" >4783.4001</td>
#       <td id="T_fe153_row7_col3" class="data row7 col3" >69.0416</td>
#       <td id="T_fe153_row7_col4" class="data row7 col4" >0.9959</td>
#       <td id="T_fe153_row7_col5" class="data row7 col5" >0.0097</td>
#       <td id="T_fe153_row7_col6" class="data row7 col6" >0.0075</td>
#       <td id="T_fe153_row7_col7" class="data row7 col7" >0.4000</td>
#     </tr>
#     <tr>
#       <th id="T_fe153_level0_row8" class="row_heading level0 row8" >dummy</th>
#       <td id="T_fe153_row8_col0" class="data row8 col0" >Dummy Regressor</td>
#       <td id="T_fe153_row8_c

# %%
# Ignoruje kolumny z tempem, ponieważ nie mają ścisłe powiązanie z czasem
exp = setup(
    data=cleaned_df,
    target='Czas', # Czas ukończenia biegu w sekundach jako zmienna docelowa
    ignore_features=['Tempo', '5 km Tempo', '10 km Tempo', '15 km Tempo', '20 km Tempo'],
    keep_features=['20 km Czas', '15 km Czas', '10 km Czas', '5 km Czas','Wiek','Płeć'],
    session_id=123,
    verbose=True,
    
)
# exp.dataset_transformed.sample(10)
# Out:
# <style type="text/css">
# #T_a9407_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a9407">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9407_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a9407_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9407_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9407_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a9407_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9407_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a9407_row1_col1" class="data row1 col1" >Czas</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a9407_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a9407_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a9407_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a9407_row3_col1" class="data row3 col1" >(17626, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a9407_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a9407_row4_col1" class="data row4 col1" >(17626, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a9407_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a9407_row5_col1" class="data row5 col1" >(12338, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a9407_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a9407_row6_col1" class="data row6 col1" >(5288, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a9407_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_a9407_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a9407_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_a9407_row8_col1" class="data row8 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a9407_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_a9407_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a9407_row10_col0" class="data row10 col0" >Keep features</td>
#       <td id="T_a9407_row10_col1" class="data row10 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a9407_row11_col0" class="data row11 col0" >Rows with missing values</td>
#       <td id="T_a9407_row11_col1" class="data row11 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a9407_row12_col0" class="data row12 col0" >Preprocess</td>
#       <td id="T_a9407_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a9407_row13_col0" class="data row13 col0" >Imputation type</td>
#       <td id="T_a9407_row13_col1" class="data row13 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a9407_row14_col0" class="data row14 col0" >Numeric imputation</td>
#       <td id="T_a9407_row14_col1" class="data row14 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a9407_row15_col0" class="data row15 col0" >Categorical imputation</td>
#       <td id="T_a9407_row15_col1" class="data row15 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a9407_row16_col0" class="data row16 col0" >Maximum one-hot encoding</td>
#       <td id="T_a9407_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a9407_row17_col0" class="data row17 col0" >Encoding method</td>
#       <td id="T_a9407_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a9407_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_a9407_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a9407_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_a9407_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a9407_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_a9407_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a9407_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_a9407_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a9407_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_a9407_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a9407_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_a9407_row23_col1" class="data row23 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a9407_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_a9407_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_a9407_row24_col1" class="data row24 col1" >decd</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model_v2 = exp.compare_models(sort='MAE')
# Out:
# <style type="text/css">
# #T_8f9da th {
#   text-align: left;
# }
# #T_8f9da_row0_col0, #T_8f9da_row1_col0, #T_8f9da_row1_col1, #T_8f9da_row1_col2, #T_8f9da_row1_col3, #T_8f9da_row1_col5, #T_8f9da_row2_col0, #T_8f9da_row2_col1, #T_8f9da_row2_col2, #T_8f9da_row2_col3, #T_8f9da_row2_col4, #T_8f9da_row2_col5, #T_8f9da_row2_col6, #T_8f9da_row3_col0, #T_8f9da_row3_col1, #T_8f9da_row3_col2, #T_8f9da_row3_col3, #T_8f9da_row3_col4, #T_8f9da_row3_col5, #T_8f9da_row3_col6, #T_8f9da_row4_col0, #T_8f9da_row4_col1, #T_8f9da_row4_col2, #T_8f9da_row4_col3, #T_8f9da_row4_col4, #T_8f9da_row4_col5, #T_8f9da_row4_col6, #T_8f9da_row5_col0, #T_8f9da_row5_col1, #T_8f9da_row5_col2, #T_8f9da_row5_col3, #T_8f9da_row5_col4, #T_8f9da_row5_col5, #T_8f9da_row5_col6, #T_8f9da_row6_col0, #T_8f9da_row6_col1, #T_8f9da_row6_col2, #T_8f9da_row6_col3, #T_8f9da_row6_col4, #T_8f9da_row6_col5, #T_8f9da_row6_col6, #T_8f9da_row7_col0, #T_8f9da_row7_col1, #T_8f9da_row7_col2, #T_8f9da_row7_col3, #T_8f9da_row7_col4, #T_8f9da_row7_col5, #T_8f9da_row7_col6, #T_8f9da_row8_col0, #T_8f9da_row8_col1, #T_8f9da_row8_col2, #T_8f9da_row8_col3, #T_8f9da_row8_col4, #T_8f9da_row8_col5, #T_8f9da_row8_col6 {
#   text-align: left;
# }
# #T_8f9da_row0_col1, #T_8f9da_row0_col2, #T_8f9da_row0_col3, #T_8f9da_row0_col4, #T_8f9da_row0_col5, #T_8f9da_row0_col6, #T_8f9da_row1_col4, #T_8f9da_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8f9da_row0_col7, #T_8f9da_row1_col7, #T_8f9da_row2_col7, #T_8f9da_row3_col7, #T_8f9da_row4_col7, #T_8f9da_row5_col7, #T_8f9da_row6_col7, #T_8f9da_row7_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8f9da_row8_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8f9da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f9da_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8f9da_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8f9da_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8f9da_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8f9da_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8f9da_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8f9da_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_8f9da_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f9da_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_8f9da_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_8f9da_row0_col1" class="data row0 col1" >3.4997</td>
#       <td id="T_8f9da_row0_col2" class="data row0 col2" >88.4462</td>
#       <td id="T_8f9da_row0_col3" class="data row0 col3" >9.0353</td>
#       <td id="T_8f9da_row0_col4" class="data row0 col4" >0.9999</td>
#       <td id="T_8f9da_row0_col5" class="data row0 col5" >0.0012</td>
#       <td id="T_8f9da_row0_col6" class="data row0 col6" >0.0005</td>
#       <td id="T_8f9da_row0_col7" class="data row0 col7" >0.7700</td>
#     </tr>
#     <tr>
#       <th id="T_8f9da_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_8f9da_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_8f9da_row1_col1" class="data row1 col1" >3.5419</td>
#       <td id="T_8f9da_row1_col2" class="data row1 col2" >113.8365</td>
#       <td id="T_8f9da_row1_col3" class="data row1 col3" >10.2224</td>
#       <td id="T_8f9da_row1_col4" class="data row1 col4" >0.9999</td>
#       <td id="T_8f9da_row1_col5" class="data row1 col5" >0.0014</td>
#       <td id="T_8f9da_row1_col6" class="data row1 col6" >0.0005</td>
#       <td id="T_8f9da_row1_col7" class="data row1 col7" >1.5120</td>
#     </tr>
#     <tr>
#       <th id="T_8f9da_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_8f9da_row2_col0" class="data row2 col0" >Decision Tree Regressor</td>
#       <td id="T_8f9da_row2_col1" class="data row2 col1" >4.7984</td>
#       <td id="T_8f9da_row2_col2" class="data row2 col2" >204.8849</td>
#       <td id="T_8f9da_row2_col3" class="data row2 col3" >13.9533</td>
#       <td id="T_8f9da_row2_col4" class="data row2 col4" >0.9998</td>
#       <td id="T_8f9da_row2_col5" class="data row2 col5" >0.0018</td>
#       <td id="T_8f9da_row2_col6" class="data row2 col6" >0.0007</td>
#       <td id="T_8f9da_row2_col7" class="data row2 col7" >0.0850</td>
#     </tr>
#     <tr>
#       <th id="T_8f9da_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_8f9da_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8f9da_row3_col1" class="data row3 col1" >12.1404</td>
#       <td id="T_8f9da_row3_col2" class="data row3 col2" >364.6940</td>
#       <td id="T_8f9da_row3_col3" class="data row3 col3" >19.0216</td>
#       <td id="T_8f9da_row3_col4" class="data row3 col4" >0.9997</td>
#       <td id="T_8f9da_row3_col5" class="data row3 col5" >0.0025</td>
#       <td id="T_8f9da_row3_col6" class="data row3 col6" >0.0016</td>
#       <td id="T_8f9da_row3_col7" class="data row3 col7" >0.1860</td>
#     </tr>
#     <tr>
#       <th id="T_8f9da_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_8f9da_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_8f9da_row4_col1" class="data row4 col1" >17.5457</td>
#       <td id="T_8f9da_row4_col2" class="data row4 col2" >616.2083</td>
#       <td id="T_8f9da_row4_col3" class="data row4 col3" >24.7882</td>
#       <td id="T_8f9da_row4_col4" class="data row4 col4" >0.9995</td>
#       <td id="T_8f9da_row4_col5" class="data row4 col5" >0.0033</td>
#       <td id="T_8f9da_row4_col6" class="data row4 col6" >0.0024</td>
#       <td id="T_8f9da_row4_col7" class="data row4 col7" >0.6410</td>
#     </tr>
#     <tr>
#       <th id="T_8f9da_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_8f9da_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_8f9da_row5_col1" class="data row5 col1" >23.4584</td>
#       <td id="T_8f9da_row5_col2" class="data row5 col2" >1168.2449</td>
#       <td id="T_8f9da_row5_col3" class="data row5 col3" >34.1439</td>
#       <td id="T_8f9da_row5_col4" class="data row5 col4" >0.9990</td>
#       <td id="T_8f9da_row5_col5" class="data row5 col5" >0.0043</td>
#       <td id="T_8f9da_row5_col6" class="data row5 col6" >0.0031</td>
#       <td id="T_8f9da_row5_col7" class="data row5 col7" >0.3730</td>
#     </tr>
#     <tr>
#       <th id="T_8f9da_level0_row6" class="row_heading level0 row6" >par</th>
#       <td id="T_8f9da_row6_col0" class="data row6 col0" >Passive Aggressive Regressor</td>
#       <td id="T_8f9da_row6_col1" class="data row6 col1" >28.7687</td>
#       <td id="T_8f9da_row6_col2" class="data row6 col2" >1426.1505</td>
#       <td id="T_8f9da_row6_col3" class="data row6 col3" >37.5555</td>
#       <td id="T_8f9da_row6_col4" class="data row6 col4" >0.9988</td>
#       <td id="T_8f9da_row6_col5" class="data row6 col5" >0.0049</td>
#       <td id="T_8f9da_row6_col6" class="data row6 col6" >0.0039</td>
#       <td id="T_8f9da_row6_col7" class="data row6 col7" >0.5030</td>
#     </tr>
#     <tr>
#       <th id="T_8f9da_level0_row7" class="row_heading level0 row7" >ada</th>
#       <td id="T_8f9da_row7_col0" class="data row7 col0" >AdaBoost Regressor</td>
#       <td id="T_8f9da_row7_col1" class="data row7 col1" >52.7692</td>
#       <td id="T_8f9da_row7_col2" class="data row7 col2" >4863.8066</td>
#       <td id="T_8f9da_row7_col3" class="data row7 col3" >69.6933</td>
#       <td id="T_8f9da_row7_col4" class="data row7 col4" >0.9958</td>
#       <td id="T_8f9da_row7_col5" class="data row7 col5" >0.0093</td>
#       <td id="T_8f9da_row7_col6" class="data row7 col6" >0.0072</td>
#       <td id="T_8f9da_row7_col7" class="data row7 col7" >0.3540</td>
#     </tr>
#     <tr>
#       <th id="T_8f9da_level0_row8" class="row_heading level0 row8" >dummy</th>
#       <td id="T_8f9da_row8_col0" class="data row8 col0" >Dummy Regressor</td>
#       <td id="T_8f

# %%
# Ignoruje kolumny z tempem, ponieważ nie mają ścisłe powiązanie z czasem
exp = setup(
    data=cleaned_df,
    target='Czas', # Czas ukończenia biegu w sekundach jako zmienna docelowa
    ignore_features=['Tempo', '5 km Tempo', '10 km Tempo', '15 km Tempo', '20 km Tempo','5 km Czas','10 km Czas','15 km Czas','20 km Czas'],
    keep_features=['Wiek', 'Płeć'],
    session_id=123,
    verbose=True,
    
)
# exp.dataset_transformed.sample(10)
# Out:
# <style type="text/css">
# #T_9e42a_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9e42a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e42a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9e42a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e42a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9e42a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9e42a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9e42a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9e42a_row1_col1" class="data row1 col1" >Czas</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9e42a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9e42a_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9e42a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9e42a_row3_col1" class="data row3 col1" >(17626, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9e42a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9e42a_row4_col1" class="data row4 col1" >(17626, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9e42a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9e42a_row5_col1" class="data row5 col1" >(12338, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9e42a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9e42a_row6_col1" class="data row6 col1" >(5288, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9e42a_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_9e42a_row7_col1" class="data row7 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9e42a_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_9e42a_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9e42a_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_9e42a_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9e42a_row10_col0" class="data row10 col0" >Keep features</td>
#       <td id="T_9e42a_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9e42a_row11_col0" class="data row11 col0" >Rows with missing values</td>
#       <td id="T_9e42a_row11_col1" class="data row11 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9e42a_row12_col0" class="data row12 col0" >Preprocess</td>
#       <td id="T_9e42a_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9e42a_row13_col0" class="data row13 col0" >Imputation type</td>
#       <td id="T_9e42a_row13_col1" class="data row13 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9e42a_row14_col0" class="data row14 col0" >Numeric imputation</td>
#       <td id="T_9e42a_row14_col1" class="data row14 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9e42a_row15_col0" class="data row15 col0" >Categorical imputation</td>
#       <td id="T_9e42a_row15_col1" class="data row15 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9e42a_row16_col0" class="data row16 col0" >Maximum one-hot encoding</td>
#       <td id="T_9e42a_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9e42a_row17_col0" class="data row17 col0" >Encoding method</td>
#       <td id="T_9e42a_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9e42a_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_9e42a_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9e42a_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_9e42a_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9e42a_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_9e42a_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9e42a_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_9e42a_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_9e42a_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_9e42a_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_9e42a_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_9e42a_row23_col1" class="data row23 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9e42a_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_9e42a_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_9e42a_row24_col1" class="data row24 col1" >18ae</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model_v3 = exp.compare_models(sort='MAE')
# Out:
# <style type="text/css">
# #T_f7db3 th {
#   text-align: left;
# }
# #T_f7db3_row0_col0, #T_f7db3_row0_col2, #T_f7db3_row0_col3, #T_f7db3_row0_col4, #T_f7db3_row0_col5, #T_f7db3_row1_col0, #T_f7db3_row1_col1, #T_f7db3_row1_col6, #T_f7db3_row2_col0, #T_f7db3_row2_col1, #T_f7db3_row2_col2, #T_f7db3_row2_col3, #T_f7db3_row2_col4, #T_f7db3_row2_col5, #T_f7db3_row2_col6, #T_f7db3_row3_col0, #T_f7db3_row3_col1, #T_f7db3_row3_col2, #T_f7db3_row3_col3, #T_f7db3_row3_col4, #T_f7db3_row3_col5, #T_f7db3_row3_col6, #T_f7db3_row4_col0, #T_f7db3_row4_col1, #T_f7db3_row4_col2, #T_f7db3_row4_col3, #T_f7db3_row4_col4, #T_f7db3_row4_col5, #T_f7db3_row4_col6, #T_f7db3_row5_col0, #T_f7db3_row5_col1, #T_f7db3_row5_col2, #T_f7db3_row5_col3, #T_f7db3_row5_col4, #T_f7db3_row5_col5, #T_f7db3_row5_col6, #T_f7db3_row6_col0, #T_f7db3_row6_col1, #T_f7db3_row6_col2, #T_f7db3_row6_col3, #T_f7db3_row6_col4, #T_f7db3_row6_col5, #T_f7db3_row6_col6, #T_f7db3_row7_col0, #T_f7db3_row7_col1, #T_f7db3_row7_col2, #T_f7db3_row7_col3, #T_f7db3_row7_col4, #T_f7db3_row7_col5, #T_f7db3_row7_col6, #T_f7db3_row8_col0, #T_f7db3_row8_col1, #T_f7db3_row8_col2, #T_f7db3_row8_col3, #T_f7db3_row8_col4, #T_f7db3_row8_col5, #T_f7db3_row8_col6 {
#   text-align: left;
# }
# #T_f7db3_row0_col1, #T_f7db3_row0_col6, #T_f7db3_row1_col2, #T_f7db3_row1_col3, #T_f7db3_row1_col4, #T_f7db3_row1_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f7db3_row0_col7, #T_f7db3_row1_col7, #T_f7db3_row2_col7, #T_f7db3_row3_col7, #T_f7db3_row4_col7, #T_f7db3_row5_col7, #T_f7db3_row6_col7, #T_f7db3_row7_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f7db3_row8_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f7db3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7db3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f7db3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f7db3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f7db3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f7db3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f7db3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f7db3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f7db3_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7db3_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_f7db3_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#       <td id="T_f7db3_row0_col1" class="data row0 col1" >28.2331</td>
#       <td id="T_f7db3_row0_col2" class="data row0 col2" >10228.0775</td>
#       <td id="T_f7db3_row0_col3" class="data row0 col3" >100.8051</td>
#       <td id="T_f7db3_row0_col4" class="data row0 col4" >0.9912</td>
#       <td id="T_f7db3_row0_col5" class="data row0 col5" >0.0124</td>
#       <td id="T_f7db3_row0_col6" class="data row0 col6" >0.0038</td>
#       <td id="T_f7db3_row0_col7" class="data row0 col7" >0.0690</td>
#     </tr>
#     <tr>
#       <th id="T_f7db3_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_f7db3_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_f7db3_row1_col1" class="data row1 col1" >30.6800</td>
#       <td id="T_f7db3_row1_col2" class="data row1 col2" >3612.9383</td>
#       <td id="T_f7db3_row1_col3" class="data row1 col3" >59.6381</td>
#       <td id="T_f7db3_row1_col4" class="data row1 col4" >0.9969</td>
#       <td id="T_f7db3_row1_col5" class="data row1 col5" >0.0074</td>
#       <td id="T_f7db3_row1_col6" class="data row1 col6" >0.0041</td>
#       <td id="T_f7db3_row1_col7" class="data row1 col7" >1.2490</td>
#     </tr>
#     <tr>
#       <th id="T_f7db3_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_f7db3_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_f7db3_row2_col1" class="data row2 col1" >33.3854</td>
#       <td id="T_f7db3_row2_col2" class="data row2 col2" >4339.9367</td>
#       <td id="T_f7db3_row2_col3" class="data row2 col3" >65.7410</td>
#       <td id="T_f7db3_row2_col4" class="data row2 col4" >0.9962</td>
#       <td id="T_f7db3_row2_col5" class="data row2 col5" >0.0080</td>
#       <td id="T_f7db3_row2_col6" class="data row2 col6" >0.0044</td>
#       <td id="T_f7db3_row2_col7" class="data row2 col7" >0.6750</td>
#     </tr>
#     <tr>
#       <th id="T_f7db3_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_f7db3_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f7db3_row3_col1" class="data row3 col1" >41.5594</td>
#       <td id="T_f7db3_row3_col2" class="data row3 col2" >4232.0995</td>
#       <td id="T_f7db3_row3_col3" class="data row3 col3" >64.8708</td>
#       <td id="T_f7db3_row3_col4" class="data row3 col4" >0.9963</td>
#       <td id="T_f7db3_row3_col5" class="data row3 col5" >0.0081</td>
#       <td id="T_f7db3_row3_col6" class="data row3 col6" >0.0055</td>
#       <td id="T_f7db3_row3_col7" class="data row3 col7" >0.1780</td>
#     </tr>
#     <tr>
#       <th id="T_f7db3_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_f7db3_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_f7db3_row4_col1" class="data row4 col1" >84.6336</td>
#       <td id="T_f7db3_row4_col2" class="data row4 col2" >16175.7127</td>
#       <td id="T_f7db3_row4_col3" class="data row4 col3" >127.0770</td>
#       <td id="T_f7db3_row4_col4" class="data row4 col4" >0.9860</td>
#       <td id="T_f7db3_row4_col5" class="data row4 col5" >0.0155</td>
#       <td id="T_f7db3_row4_col6" class="data row4 col6" >0.0109</td>
#       <td id="T_f7db3_row4_col7" class="data row4 col7" >0.5320</td>
#     </tr>
#     <tr>
#       <th id="T_f7db3_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_f7db3_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_f7db3_row5_col1" class="data row5 col1" >162.8559</td>
#       <td id="T_f7db3_row5_col2" class="data row5 col2" >47856.7350</td>
#       <td id="T_f7db3_row5_col3" class="data row5 col3" >218.7102</td>
#       <td id="T_f7db3_row5_col4" class="data row5 col4" >0.9586</td>
#       <td id="T_f7db3_row5_col5" class="data row5 col5" >0.0273</td>
#       <td id="T_f7db3_row5_col6" class="data row5 col6" >0.0212</td>
#       <td id="T_f7db3_row5_col7" class="data row5 col7" >0.2650</td>
#     </tr>
#     <tr>
#       <th id="T_f7db3_level0_row6" class="row_heading level0 row6" >huber</th>
#       <td id="T_f7db3_row6_col0" class="data row6 col0" >Huber Regressor</td>
#       <td id="T_f7db3_row6_col1" class="data row6 col1" >192.3926</td>
#       <td id="T_f7db3_row6_col2" class="data row6 col2" >79500.2259</td>
#       <td id="T_f7db3_row6_col3" class="data row6 col3" >281.8762</td>
#       <td id="T_f7db3_row6_col4" class="data row6 col4" >0.9313</td>
#       <td id="T_f7db3_row6_col5" class="data row6 col5" >0.0384</td>
#       <td id="T_f7db3_row6_col6" class="data row6 col6" >0.0262</td>
#       <td id="T_f7db3_row6_col7" class="data row6 col7" >0.3550</td>
#     </tr>
#     <tr>
#       <th id="T_f7db3_level0_row7" class="row_heading level0 row7" >par</th>
#       <td id="T_f7db3_row7_col0" class="data row7 col0" >Passive Aggressive Regressor</td>
#       <td id="T_f7db3_row7_col1" class="data row7 col1" >266.0228</td>
#       <td id="T_f7db3_row7_col2" class="data row7 col2" >120997.9046</td>
#       <td id="T_f7db3_row7_col3" class="data row7 col3" >341.5665</td>
#       <td id="T_f7db3_row7_col4" class="data row7 col4" >0.8951</td>
#       <td id="T_f7db3_row7_col5" class="data row7 col5" >0.0464</td>
#       <td id="T_f7db3_row7_col6" class="data row7 col6" >0.0364</td>
#       <td id="T_f7db3_row7_col7" class="data row7 col7" >0.4770</td>
#     </tr>
#     <tr>
#       <th id="T_f7db3_level0_row8" class="row_heading level0 row8" >dummy</th>
#       <td id="T_f7db3_row8_col0" class="data row8 col0" >Dummy Regressor

# %%
# Ignoruje kolumny z tempem, ponieważ nie mają ścisłe powiązanie z czasem, oraz sprawdzam różne dystanse czasu
exp = setup(
    data=cleaned_df,
    target='Czas', # Czas ukończenia biegu w sekundach jako zmienna docelowa
    ignore_features=['Tempo', '5 km Tempo', '10 km Tempo', '15 km Tempo', '20 km Tempo','10 km Czas','15 km Czas', '20 km Czas'],
    keep_features=['5 km Czas','Wiek','Płeć'],
    session_id=123,
    verbose=True,
    
)
# exp.dataset_transformed.sample(10)
# Out:
# <style type="text/css">
# #T_688f1_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_688f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_688f1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_688f1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_688f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_688f1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_688f1_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_688f1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_688f1_row1_col1" class="data row1 col1" >Czas</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_688f1_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_688f1_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_688f1_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_688f1_row3_col1" class="data row3 col1" >(17626, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_688f1_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_688f1_row4_col1" class="data row4 col1" >(17626, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_688f1_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_688f1_row5_col1" class="data row5 col1" >(12338, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_688f1_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_688f1_row6_col1" class="data row6 col1" >(5288, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_688f1_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_688f1_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_688f1_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_688f1_row8_col1" class="data row8 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_688f1_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_688f1_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_688f1_row10_col0" class="data row10 col0" >Keep features</td>
#       <td id="T_688f1_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_688f1_row11_col0" class="data row11 col0" >Rows with missing values</td>
#       <td id="T_688f1_row11_col1" class="data row11 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_688f1_row12_col0" class="data row12 col0" >Preprocess</td>
#       <td id="T_688f1_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_688f1_row13_col0" class="data row13 col0" >Imputation type</td>
#       <td id="T_688f1_row13_col1" class="data row13 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_688f1_row14_col0" class="data row14 col0" >Numeric imputation</td>
#       <td id="T_688f1_row14_col1" class="data row14 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_688f1_row15_col0" class="data row15 col0" >Categorical imputation</td>
#       <td id="T_688f1_row15_col1" class="data row15 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_688f1_row16_col0" class="data row16 col0" >Maximum one-hot encoding</td>
#       <td id="T_688f1_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_688f1_row17_col0" class="data row17 col0" >Encoding method</td>
#       <td id="T_688f1_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_688f1_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_688f1_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_688f1_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_688f1_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_688f1_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_688f1_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_688f1_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_688f1_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_688f1_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_688f1_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_688f1_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_688f1_row23_col1" class="data row23 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_688f1_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_688f1_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_688f1_row24_col1" class="data row24 col1" >f426</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model_v4 = exp.compare_models(sort='MAE')
# Out:
# <style type="text/css">
# #T_eddd0 th {
#   text-align: left;
# }
# #T_eddd0_row0_col0, #T_eddd0_row1_col0, #T_eddd0_row1_col1, #T_eddd0_row1_col2, #T_eddd0_row1_col3, #T_eddd0_row1_col4, #T_eddd0_row1_col5, #T_eddd0_row1_col6, #T_eddd0_row2_col0, #T_eddd0_row2_col1, #T_eddd0_row2_col2, #T_eddd0_row2_col3, #T_eddd0_row2_col4, #T_eddd0_row2_col5, #T_eddd0_row2_col6, #T_eddd0_row3_col0, #T_eddd0_row3_col1, #T_eddd0_row3_col2, #T_eddd0_row3_col3, #T_eddd0_row3_col4, #T_eddd0_row3_col5, #T_eddd0_row3_col6, #T_eddd0_row4_col0, #T_eddd0_row4_col1, #T_eddd0_row4_col2, #T_eddd0_row4_col3, #T_eddd0_row4_col4, #T_eddd0_row4_col5, #T_eddd0_row4_col6, #T_eddd0_row5_col0, #T_eddd0_row5_col1, #T_eddd0_row5_col2, #T_eddd0_row5_col3, #T_eddd0_row5_col4, #T_eddd0_row5_col5, #T_eddd0_row5_col6, #T_eddd0_row6_col0, #T_eddd0_row6_col1, #T_eddd0_row6_col2, #T_eddd0_row6_col3, #T_eddd0_row6_col4, #T_eddd0_row6_col5, #T_eddd0_row6_col6, #T_eddd0_row7_col0, #T_eddd0_row7_col1, #T_eddd0_row7_col2, #T_eddd0_row7_col3, #T_eddd0_row7_col4, #T_eddd0_row7_col5, #T_eddd0_row7_col6, #T_eddd0_row8_col0, #T_eddd0_row8_col1, #T_eddd0_row8_col2, #T_eddd0_row8_col3, #T_eddd0_row8_col4, #T_eddd0_row8_col5, #T_eddd0_row8_col6 {
#   text-align: left;
# }
# #T_eddd0_row0_col1, #T_eddd0_row0_col2, #T_eddd0_row0_col3, #T_eddd0_row0_col4, #T_eddd0_row0_col5, #T_eddd0_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_eddd0_row0_col7, #T_eddd0_row1_col7, #T_eddd0_row2_col7, #T_eddd0_row3_col7, #T_eddd0_row4_col7, #T_eddd0_row5_col7, #T_eddd0_row6_col7, #T_eddd0_row7_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_eddd0_row8_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_eddd0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eddd0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_eddd0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_eddd0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_eddd0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_eddd0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_eddd0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_eddd0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_eddd0_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eddd0_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_eddd0_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_eddd0_row0_col1" class="data row0 col1" >18.4176</td>
#       <td id="T_eddd0_row0_col2" class="data row0 col2" >827.6158</td>
#       <td id="T_eddd0_row0_col3" class="data row0 col3" >28.7160</td>
#       <td id="T_eddd0_row0_col4" class="data row0 col4" >0.9993</td>
#       <td id="T_eddd0_row0_col5" class="data row0 col5" >0.0038</td>
#       <td id="T_eddd0_row0_col6" class="data row0 col6" >0.0026</td>
#       <td id="T_eddd0_row0_col7" class="data row0 col7" >0.7030</td>
#     </tr>
#     <tr>
#       <th id="T_eddd0_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_eddd0_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_eddd0_row1_col1" class="data row1 col1" >26.9318</td>
#       <td id="T_eddd0_row1_col2" class="data row1 col2" >2277.1038</td>
#       <td id="T_eddd0_row1_col3" class="data row1 col3" >47.4767</td>
#       <td id="T_eddd0_row1_col4" class="data row1 col4" >0.9980</td>
#       <td id="T_eddd0_row1_col5" class="data row1 col5" >0.0061</td>
#       <td id="T_eddd0_row1_col6" class="data row1 col6" >0.0036</td>
#       <td id="T_eddd0_row1_col7" class="data row1 col7" >1.3330</td>
#     </tr>
#     <tr>
#       <th id="T_eddd0_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_eddd0_row2_col0" class="data row2 col0" >Decision Tree Regressor</td>
#       <td id="T_eddd0_row2_col1" class="data row2 col1" >27.9701</td>
#       <td id="T_eddd0_row2_col2" class="data row2 col2" >7801.1604</td>
#       <td id="T_eddd0_row2_col3" class="data row2 col3" >87.8099</td>
#       <td id="T_eddd0_row2_col4" class="data row2 col4" >0.9932</td>
#       <td id="T_eddd0_row2_col5" class="data row2 col5" >0.0110</td>
#       <td id="T_eddd0_row2_col6" class="data row2 col6" >0.0037</td>
#       <td id="T_eddd0_row2_col7" class="data row2 col7" >0.0710</td>
#     </tr>
#     <tr>
#       <th id="T_eddd0_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_eddd0_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_eddd0_row3_col1" class="data row3 col1" >31.7205</td>
#       <td id="T_eddd0_row3_col2" class="data row3 col2" >2093.0274</td>
#       <td id="T_eddd0_row3_col3" class="data row3 col3" >45.7006</td>
#       <td id="T_eddd0_row3_col4" class="data row3 col4" >0.9982</td>
#       <td id="T_eddd0_row3_col5" class="data row3 col5" >0.0059</td>
#       <td id="T_eddd0_row3_col6" class="data row3 col6" >0.0043</td>
#       <td id="T_eddd0_row3_col7" class="data row3 col7" >0.1780</td>
#     </tr>
#     <tr>
#       <th id="T_eddd0_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_eddd0_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_eddd0_row4_col1" class="data row4 col1" >55.1459</td>
#       <td id="T_eddd0_row4_col2" class="data row4 col2" >5288.9949</td>
#       <td id="T_eddd0_row4_col3" class="data row4 col3" >72.7031</td>
#       <td id="T_eddd0_row4_col4" class="data row4 col4" >0.9954</td>
#       <td id="T_eddd0_row4_col5" class="data row4 col5" >0.0092</td>
#       <td id="T_eddd0_row4_col6" class="data row4 col6" >0.0073</td>
#       <td id="T_eddd0_row4_col7" class="data row4 col7" >0.5450</td>
#     </tr>
#     <tr>
#       <th id="T_eddd0_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_eddd0_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_eddd0_row5_col1" class="data row5 col1" >97.1289</td>
#       <td id="T_eddd0_row5_col2" class="data row5 col2" >21472.0059</td>
#       <td id="T_eddd0_row5_col3" class="data row5 col3" >146.3865</td>
#       <td id="T_eddd0_row5_col4" class="data row5 col4" >0.9814</td>
#       <td id="T_eddd0_row5_col5" class="data row5 col5" >0.0183</td>
#       <td id="T_eddd0_row5_col6" class="data row5 col6" >0.0128</td>
#       <td id="T_eddd0_row5_col7" class="data row5 col7" >0.3630</td>
#     </tr>
#     <tr>
#       <th id="T_eddd0_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_eddd0_row6_col0" class="data row6 col0" >AdaBoost Regressor</td>
#       <td id="T_eddd0_row6_col1" class="data row6 col1" >138.6206</td>
#       <td id="T_eddd0_row6_col2" class="data row6 col2" >33789.4360</td>
#       <td id="T_eddd0_row6_col3" class="data row6 col3" >183.7833</td>
#       <td id="T_eddd0_row6_col4" class="data row6 col4" >0.9708</td>
#       <td id="T_eddd0_row6_col5" class="data row6 col5" >0.0232</td>
#       <td id="T_eddd0_row6_col6" class="data row6 col6" >0.0181</td>
#       <td id="T_eddd0_row6_col7" class="data row6 col7" >0.2770</td>
#     </tr>
#     <tr>
#       <th id="T_eddd0_level0_row7" class="row_heading level0 row7" >par</th>
#       <td id="T_eddd0_row7_col0" class="data row7 col0" >Passive Aggressive Regressor</td>
#       <td id="T_eddd0_row7_col1" class="data row7 col1" >147.6776</td>
#       <td id="T_eddd0_row7_col2" class="data row7 col2" >38771.9133</td>
#       <td id="T_eddd0_row7_col3" class="data row7 col3" >190.9279</td>
#       <td id="T_eddd0_row7_col4" class="data row7 col4" >0.9665</td>
#       <td id="T_eddd0_row7_col5" class="data row7 col5" >0.0246</td>
#       <td id="T_eddd0_row7_col6" class="data row7 col6" >0.0198</td>
#       <td id="T_eddd0_row7_col7" class="data row7 col7" >0.4960</td>
#     </tr>
#     <tr>
#       <th id="T_eddd0_level0_row8" class="row_heading level0 row8" >dummy</th>
#       <td id="T_eddd0_row8_col0" class="data row8 col0" >Dummy Regressor</td>

# %%
# Ignoruje kolumny z tempem, ponieważ nie mają ścisłe powiązanie z czasem, oraz sprawdzam różne dystansy czasu
exp = setup(
    data=cleaned_df,
    target='Czas', # Czas ukończenia biegu w sekundach jako zmienna docelowa
    ignore_features=['Tempo', '5 km Tempo', '10 km Tempo', '15 km Tempo', '20 km Tempo','15 km Czas', '20 km Czas'],
    keep_features=['10 km Czas', '5 km Czas','Wiek','Płeć'],
    session_id=123,
    verbose=True,
    
)
# exp.dataset_transformed.sample(10)
# Out:
# <style type="text/css">
# #T_14f15_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_14f15">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14f15_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_14f15_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14f15_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14f15_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_14f15_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_14f15_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_14f15_row1_col1" class="data row1 col1" >Czas</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_14f15_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_14f15_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_14f15_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_14f15_row3_col1" class="data row3 col1" >(17626, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_14f15_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_14f15_row4_col1" class="data row4 col1" >(17626, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_14f15_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_14f15_row5_col1" class="data row5 col1" >(12338, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_14f15_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_14f15_row6_col1" class="data row6 col1" >(5288, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_14f15_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_14f15_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_14f15_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_14f15_row8_col1" class="data row8 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_14f15_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_14f15_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_14f15_row10_col0" class="data row10 col0" >Keep features</td>
#       <td id="T_14f15_row10_col1" class="data row10 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_14f15_row11_col0" class="data row11 col0" >Rows with missing values</td>
#       <td id="T_14f15_row11_col1" class="data row11 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_14f15_row12_col0" class="data row12 col0" >Preprocess</td>
#       <td id="T_14f15_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_14f15_row13_col0" class="data row13 col0" >Imputation type</td>
#       <td id="T_14f15_row13_col1" class="data row13 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_14f15_row14_col0" class="data row14 col0" >Numeric imputation</td>
#       <td id="T_14f15_row14_col1" class="data row14 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_14f15_row15_col0" class="data row15 col0" >Categorical imputation</td>
#       <td id="T_14f15_row15_col1" class="data row15 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_14f15_row16_col0" class="data row16 col0" >Maximum one-hot encoding</td>
#       <td id="T_14f15_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_14f15_row17_col0" class="data row17 col0" >Encoding method</td>
#       <td id="T_14f15_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_14f15_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_14f15_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_14f15_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_14f15_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_14f15_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_14f15_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_14f15_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_14f15_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_14f15_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_14f15_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_14f15_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_14f15_row23_col1" class="data row23 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_14f15_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_14f15_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_14f15_row24_col1" class="data row24 col1" >1a92</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model_v5 = exp.compare_models(sort='MAE')
# Out:
# <style type="text/css">
# #T_b5cd2 th {
#   text-align: left;
# }
# #T_b5cd2_row0_col0, #T_b5cd2_row1_col0, #T_b5cd2_row1_col1, #T_b5cd2_row1_col2, #T_b5cd2_row1_col3, #T_b5cd2_row1_col4, #T_b5cd2_row1_col5, #T_b5cd2_row1_col6, #T_b5cd2_row2_col0, #T_b5cd2_row2_col1, #T_b5cd2_row2_col2, #T_b5cd2_row2_col3, #T_b5cd2_row2_col4, #T_b5cd2_row2_col5, #T_b5cd2_row2_col6, #T_b5cd2_row3_col0, #T_b5cd2_row3_col1, #T_b5cd2_row3_col2, #T_b5cd2_row3_col3, #T_b5cd2_row3_col4, #T_b5cd2_row3_col5, #T_b5cd2_row3_col6, #T_b5cd2_row4_col0, #T_b5cd2_row4_col1, #T_b5cd2_row4_col2, #T_b5cd2_row4_col3, #T_b5cd2_row4_col4, #T_b5cd2_row4_col5, #T_b5cd2_row4_col6, #T_b5cd2_row5_col0, #T_b5cd2_row5_col1, #T_b5cd2_row5_col2, #T_b5cd2_row5_col3, #T_b5cd2_row5_col4, #T_b5cd2_row5_col5, #T_b5cd2_row5_col6, #T_b5cd2_row6_col0, #T_b5cd2_row6_col1, #T_b5cd2_row6_col2, #T_b5cd2_row6_col3, #T_b5cd2_row6_col4, #T_b5cd2_row6_col5, #T_b5cd2_row6_col6, #T_b5cd2_row7_col0, #T_b5cd2_row7_col1, #T_b5cd2_row7_col2, #T_b5cd2_row7_col3, #T_b5cd2_row7_col4, #T_b5cd2_row7_col5, #T_b5cd2_row7_col6, #T_b5cd2_row8_col0, #T_b5cd2_row8_col1, #T_b5cd2_row8_col2, #T_b5cd2_row8_col3, #T_b5cd2_row8_col4, #T_b5cd2_row8_col5, #T_b5cd2_row8_col6 {
#   text-align: left;
# }
# #T_b5cd2_row0_col1, #T_b5cd2_row0_col2, #T_b5cd2_row0_col3, #T_b5cd2_row0_col4, #T_b5cd2_row0_col5, #T_b5cd2_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_b5cd2_row0_col7, #T_b5cd2_row1_col7, #T_b5cd2_row2_col7, #T_b5cd2_row3_col7, #T_b5cd2_row4_col7, #T_b5cd2_row5_col7, #T_b5cd2_row6_col7, #T_b5cd2_row7_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_b5cd2_row8_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_b5cd2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5cd2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b5cd2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_b5cd2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_b5cd2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_b5cd2_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_b5cd2_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_b5cd2_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_b5cd2_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5cd2_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_b5cd2_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_b5cd2_row0_col1" class="data row0 col1" >11.6598</td>
#       <td id="T_b5cd2_row0_col2" class="data row0 col2" >361.1277</td>
#       <td id="T_b5cd2_row0_col3" class="data row0 col3" >18.9201</td>
#       <td id="T_b5cd2_row0_col4" class="data row0 col4" >0.9997</td>
#       <td id="T_b5cd2_row0_col5" class="data row0 col5" >0.0026</td>
#       <td id="T_b5cd2_row0_col6" class="data row0 col6" >0.0017</td>
#       <td id="T_b5cd2_row0_col7" class="data row0 col7" >0.7350</td>
#     </tr>
#     <tr>
#       <th id="T_b5cd2_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_b5cd2_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_b5cd2_row1_col1" class="data row1 col1" >16.5644</td>
#       <td id="T_b5cd2_row1_col2" class="data row1 col2" >722.1398</td>
#       <td id="T_b5cd2_row1_col3" class="data row1 col3" >26.8244</td>
#       <td id="T_b5cd2_row1_col4" class="data row1 col4" >0.9994</td>
#       <td id="T_b5cd2_row1_col5" class="data row1 col5" >0.0036</td>
#       <td id="T_b5cd2_row1_col6" class="data row1 col6" >0.0023</td>
#       <td id="T_b5cd2_row1_col7" class="data row1 col7" >1.4210</td>
#     </tr>
#     <tr>
#       <th id="T_b5cd2_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_b5cd2_row2_col0" class="data row2 col0" >Decision Tree Regressor</td>
#       <td id="T_b5cd2_row2_col1" class="data row2 col1" >18.4394</td>
#       <td id="T_b5cd2_row2_col2" class="data row2 col2" >2329.3348</td>
#       <td id="T_b5cd2_row2_col3" class="data row2 col3" >48.1160</td>
#       <td id="T_b5cd2_row2_col4" class="data row2 col4" >0.9980</td>
#       <td id="T_b5cd2_row2_col5" class="data row2 col5" >0.0064</td>
#       <td id="T_b5cd2_row2_col6" class="data row2 col6" >0.0025</td>
#       <td id="T_b5cd2_row2_col7" class="data row2 col7" >0.0730</td>
#     </tr>
#     <tr>
#       <th id="T_b5cd2_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_b5cd2_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_b5cd2_row3_col1" class="data row3 col1" >21.7142</td>
#       <td id="T_b5cd2_row3_col2" class="data row3 col2" >985.2137</td>
#       <td id="T_b5cd2_row3_col3" class="data row3 col3" >31.3606</td>
#       <td id="T_b5cd2_row3_col4" class="data row3 col4" >0.9991</td>
#       <td id="T_b5cd2_row3_col5" class="data row3 col5" >0.0041</td>
#       <td id="T_b5cd2_row3_col6" class="data row3 col6" >0.0029</td>
#       <td id="T_b5cd2_row3_col7" class="data row3 col7" >0.1870</td>
#     </tr>
#     <tr>
#       <th id="T_b5cd2_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_b5cd2_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_b5cd2_row4_col1" class="data row4 col1" >36.9624</td>
#       <td id="T_b5cd2_row4_col2" class="data row4 col2" >2156.4155</td>
#       <td id="T_b5cd2_row4_col3" class="data row4 col3" >46.4197</td>
#       <td id="T_b5cd2_row4_col4" class="data row4 col4" >0.9981</td>
#       <td id="T_b5cd2_row4_col5" class="data row4 col5" >0.0061</td>
#       <td id="T_b5cd2_row4_col6" class="data row4 col6" >0.0050</td>
#       <td id="T_b5cd2_row4_col7" class="data row4 col7" >0.5800</td>
#     </tr>
#     <tr>
#       <th id="T_b5cd2_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_b5cd2_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_b5cd2_row5_col1" class="data row5 col1" >64.8831</td>
#       <td id="T_b5cd2_row5_col2" class="data row5 col2" >10738.9192</td>
#       <td id="T_b5cd2_row5_col3" class="data row5 col3" >103.5334</td>
#       <td id="T_b5cd2_row5_col4" class="data row5 col4" >0.9907</td>
#       <td id="T_b5cd2_row5_col5" class="data row5 col5" >0.0130</td>
#       <td id="T_b5cd2_row5_col6" class="data row5 col6" >0.0085</td>
#       <td id="T_b5cd2_row5_col7" class="data row5 col7" >0.3630</td>
#     </tr>
#     <tr>
#       <th id="T_b5cd2_level0_row6" class="row_heading level0 row6" >par</th>
#       <td id="T_b5cd2_row6_col0" class="data row6 col0" >Passive Aggressive Regressor</td>
#       <td id="T_b5cd2_row6_col1" class="data row6 col1" >80.8011</td>
#       <td id="T_b5cd2_row6_col2" class="data row6 col2" >13019.7096</td>
#       <td id="T_b5cd2_row6_col3" class="data row6 col3" >113.1293</td>
#       <td id="T_b5cd2_row6_col4" class="data row6 col4" >0.9888</td>
#       <td id="T_b5cd2_row6_col5" class="data row6 col5" >0.0146</td>
#       <td id="T_b5cd2_row6_col6" class="data row6 col6" >0.0109</td>
#       <td id="T_b5cd2_row6_col7" class="data row6 col7" >0.4950</td>
#     </tr>
#     <tr>
#       <th id="T_b5cd2_level0_row7" class="row_heading level0 row7" >ada</th>
#       <td id="T_b5cd2_row7_col0" class="data row7 col0" >AdaBoost Regressor</td>
#       <td id="T_b5cd2_row7_col1" class="data row7 col1" >117.9124</td>
#       <td id="T_b5cd2_row7_col2" class="data row7 col2" >24081.0889</td>
#       <td id="T_b5cd2_row7_col3" class="data row7 col3" >155.1355</td>
#       <td id="T_b5cd2_row7_col4" class="data row7 col4" >0.9791</td>
#       <td id="T_b5cd2_row7_col5" class="data row7 col5" >0.0200</td>
#       <td id="T_b5cd2_row7_col6" class="data row7 col6" >0.0157</td>
#       <td id="T_b5cd2_row7_col7" class="data row7 col7" >0.2930</td>
#     </tr>
#     <tr>
#       <th id="T_b5cd2_level0_row8" class="row_heading level0 row8" >dummy</th>
#       <td id="T_b5cd2_row8_col0" class="data row8 col0" >Dummy Regressor</td>

# %%
# Ignoruje kolumny z tempem, ponieważ nie mają ścisłe powiązanie z czasem, oraz sprawdzam różne dystanse czasu
exp = setup(
    data=cleaned_df,
    target='Czas', # Czas ukończenia biegu w sekundach jako zmienna docelowa
    ignore_features=['Tempo', '5 km Tempo', '10 km Tempo', '15 km Tempo', '20 km Tempo', '20 km Czas'],
    keep_features=['15 km Czas', '10 km Czas', '5 km Czas','Wiek','Płeć'],
    session_id=123,
    verbose=True,
    
)
# exp.dataset_transformed.sample(10)
# Out:
# <style type="text/css">
# #T_825f7_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_825f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_825f7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_825f7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_825f7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_825f7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_825f7_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_825f7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_825f7_row1_col1" class="data row1 col1" >Czas</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_825f7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_825f7_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_825f7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_825f7_row3_col1" class="data row3 col1" >(17626, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_825f7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_825f7_row4_col1" class="data row4 col1" >(17626, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_825f7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_825f7_row5_col1" class="data row5 col1" >(12338, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_825f7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_825f7_row6_col1" class="data row6 col1" >(5288, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_825f7_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_825f7_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_825f7_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_825f7_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_825f7_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_825f7_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_825f7_row10_col0" class="data row10 col0" >Keep features</td>
#       <td id="T_825f7_row10_col1" class="data row10 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_825f7_row11_col0" class="data row11 col0" >Rows with missing values</td>
#       <td id="T_825f7_row11_col1" class="data row11 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_825f7_row12_col0" class="data row12 col0" >Preprocess</td>
#       <td id="T_825f7_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_825f7_row13_col0" class="data row13 col0" >Imputation type</td>
#       <td id="T_825f7_row13_col1" class="data row13 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_825f7_row14_col0" class="data row14 col0" >Numeric imputation</td>
#       <td id="T_825f7_row14_col1" class="data row14 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_825f7_row15_col0" class="data row15 col0" >Categorical imputation</td>
#       <td id="T_825f7_row15_col1" class="data row15 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_825f7_row16_col0" class="data row16 col0" >Maximum one-hot encoding</td>
#       <td id="T_825f7_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_825f7_row17_col0" class="data row17 col0" >Encoding method</td>
#       <td id="T_825f7_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_825f7_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_825f7_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_825f7_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_825f7_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_825f7_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_825f7_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_825f7_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_825f7_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_825f7_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_825f7_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_825f7_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_825f7_row23_col1" class="data row23 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_825f7_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_825f7_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_825f7_row24_col1" class="data row24 col1" >0dc6</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model_v6 = exp.compare_models(sort='MAE')
# Out:
# <style type="text/css">
# #T_d22c8 th {
#   text-align: left;
# }
# #T_d22c8_row0_col0, #T_d22c8_row1_col0, #T_d22c8_row1_col1, #T_d22c8_row1_col2, #T_d22c8_row1_col3, #T_d22c8_row1_col4, #T_d22c8_row1_col5, #T_d22c8_row1_col6, #T_d22c8_row2_col0, #T_d22c8_row2_col1, #T_d22c8_row2_col2, #T_d22c8_row2_col3, #T_d22c8_row2_col4, #T_d22c8_row2_col5, #T_d22c8_row2_col6, #T_d22c8_row3_col0, #T_d22c8_row3_col1, #T_d22c8_row3_col2, #T_d22c8_row3_col3, #T_d22c8_row3_col4, #T_d22c8_row3_col5, #T_d22c8_row3_col6, #T_d22c8_row4_col0, #T_d22c8_row4_col1, #T_d22c8_row4_col2, #T_d22c8_row4_col3, #T_d22c8_row4_col4, #T_d22c8_row4_col5, #T_d22c8_row4_col6, #T_d22c8_row5_col0, #T_d22c8_row5_col1, #T_d22c8_row5_col2, #T_d22c8_row5_col3, #T_d22c8_row5_col4, #T_d22c8_row5_col5, #T_d22c8_row5_col6, #T_d22c8_row6_col0, #T_d22c8_row6_col1, #T_d22c8_row6_col2, #T_d22c8_row6_col3, #T_d22c8_row6_col4, #T_d22c8_row6_col5, #T_d22c8_row6_col6, #T_d22c8_row7_col0, #T_d22c8_row7_col1, #T_d22c8_row7_col2, #T_d22c8_row7_col3, #T_d22c8_row7_col4, #T_d22c8_row7_col5, #T_d22c8_row7_col6, #T_d22c8_row8_col0, #T_d22c8_row8_col1, #T_d22c8_row8_col2, #T_d22c8_row8_col3, #T_d22c8_row8_col4, #T_d22c8_row8_col5, #T_d22c8_row8_col6 {
#   text-align: left;
# }
# #T_d22c8_row0_col1, #T_d22c8_row0_col2, #T_d22c8_row0_col3, #T_d22c8_row0_col4, #T_d22c8_row0_col5, #T_d22c8_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d22c8_row0_col7, #T_d22c8_row1_col7, #T_d22c8_row2_col7, #T_d22c8_row3_col7, #T_d22c8_row4_col7, #T_d22c8_row5_col7, #T_d22c8_row6_col7, #T_d22c8_row7_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d22c8_row8_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d22c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d22c8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d22c8_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d22c8_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d22c8_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d22c8_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d22c8_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d22c8_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d22c8_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d22c8_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_d22c8_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_d22c8_row0_col1" class="data row0 col1" >10.8587</td>
#       <td id="T_d22c8_row0_col2" class="data row0 col2" >348.7463</td>
#       <td id="T_d22c8_row0_col3" class="data row0 col3" >18.5810</td>
#       <td id="T_d22c8_row0_col4" class="data row0 col4" >0.9997</td>
#       <td id="T_d22c8_row0_col5" class="data row0 col5" >0.0025</td>
#       <td id="T_d22c8_row0_col6" class="data row0 col6" >0.0015</td>
#       <td id="T_d22c8_row0_col7" class="data row0 col7" >0.7780</td>
#     </tr>
#     <tr>
#       <th id="T_d22c8_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_d22c8_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_d22c8_row1_col1" class="data row1 col1" >15.6124</td>
#       <td id="T_d22c8_row1_col2" class="data row1 col2" >711.5376</td>
#       <td id="T_d22c8_row1_col3" class="data row1 col3" >26.6180</td>
#       <td id="T_d22c8_row1_col4" class="data row1 col4" >0.9994</td>
#       <td id="T_d22c8_row1_col5" class="data row1 col5" >0.0035</td>
#       <td id="T_d22c8_row1_col6" class="data row1 col6" >0.0021</td>
#       <td id="T_d22c8_row1_col7" class="data row1 col7" >1.4780</td>
#     </tr>
#     <tr>
#       <th id="T_d22c8_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_d22c8_row2_col0" class="data row2 col0" >Decision Tree Regressor</td>
#       <td id="T_d22c8_row2_col1" class="data row2 col1" >18.8366</td>
#       <td id="T_d22c8_row2_col2" class="data row2 col2" >1944.1457</td>
#       <td id="T_d22c8_row2_col3" class="data row2 col3" >43.9002</td>
#       <td id="T_d22c8_row2_col4" class="data row2 col4" >0.9983</td>
#       <td id="T_d22c8_row2_col5" class="data row2 col5" >0.0057</td>
#       <td id="T_d22c8_row2_col6" class="data row2 col6" >0.0025</td>
#       <td id="T_d22c8_row2_col7" class="data row2 col7" >0.0750</td>
#     </tr>
#     <tr>
#       <th id="T_d22c8_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_d22c8_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d22c8_row3_col1" class="data row3 col1" >21.7695</td>
#       <td id="T_d22c8_row3_col2" class="data row3 col2" >958.2847</td>
#       <td id="T_d22c8_row3_col3" class="data row3 col3" >30.9105</td>
#       <td id="T_d22c8_row3_col4" class="data row3 col4" >0.9992</td>
#       <td id="T_d22c8_row3_col5" class="data row3 col5" >0.0041</td>
#       <td id="T_d22c8_row3_col6" class="data row3 col6" >0.0029</td>
#       <td id="T_d22c8_row3_col7" class="data row3 col7" >0.1880</td>
#     </tr>
#     <tr>
#       <th id="T_d22c8_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_d22c8_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_d22c8_row4_col1" class="data row4 col1" >35.1631</td>
#       <td id="T_d22c8_row4_col2" class="data row4 col2" >2065.0989</td>
#       <td id="T_d22c8_row4_col3" class="data row4 col3" >45.4072</td>
#       <td id="T_d22c8_row4_col4" class="data row4 col4" >0.9982</td>
#       <td id="T_d22c8_row4_col5" class="data row4 col5" >0.0060</td>
#       <td id="T_d22c8_row4_col6" class="data row4 col6" >0.0048</td>
#       <td id="T_d22c8_row4_col7" class="data row4 col7" >0.6160</td>
#     </tr>
#     <tr>
#       <th id="T_d22c8_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_d22c8_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_d22c8_row5_col1" class="data row5 col1" >46.1227</td>
#       <td id="T_d22c8_row5_col2" class="data row5 col2" >5305.3914</td>
#       <td id="T_d22c8_row5_col3" class="data row5 col3" >72.7819</td>
#       <td id="T_d22c8_row5_col4" class="data row5 col4" >0.9954</td>
#       <td id="T_d22c8_row5_col5" class="data row5 col5" >0.0093</td>
#       <td id="T_d22c8_row5_col6" class="data row5 col6" >0.0061</td>
#       <td id="T_d22c8_row5_col7" class="data row5 col7" >0.3750</td>
#     </tr>
#     <tr>
#       <th id="T_d22c8_level0_row6" class="row_heading level0 row6" >par</th>
#       <td id="T_d22c8_row6_col0" class="data row6 col0" >Passive Aggressive Regressor</td>
#       <td id="T_d22c8_row6_col1" class="data row6 col1" >54.7184</td>
#       <td id="T_d22c8_row6_col2" class="data row6 col2" >5701.8312</td>
#       <td id="T_d22c8_row6_col3" class="data row6 col3" >72.8461</td>
#       <td id="T_d22c8_row6_col4" class="data row6 col4" >0.9951</td>
#       <td id="T_d22c8_row6_col5" class="data row6 col5" >0.0092</td>
#       <td id="T_d22c8_row6_col6" class="data row6 col6" >0.0073</td>
#       <td id="T_d22c8_row6_col7" class="data row6 col7" >0.5140</td>
#     </tr>
#     <tr>
#       <th id="T_d22c8_level0_row7" class="row_heading level0 row7" >ada</th>
#       <td id="T_d22c8_row7_col0" class="data row7 col0" >AdaBoost Regressor</td>
#       <td id="T_d22c8_row7_col1" class="data row7 col1" >98.7383</td>
#       <td id="T_d22c8_row7_col2" class="data row7 col2" >16417.5192</td>
#       <td id="T_d22c8_row7_col3" class="data row7 col3" >128.1030</td>
#       <td id="T_d22c8_row7_col4" class="data row7 col4" >0.9858</td>
#       <td id="T_d22c8_row7_col5" class="data row7 col5" >0.0167</td>
#       <td id="T_d22c8_row7_col6" class="data row7 col6" >0.0132</td>
#       <td id="T_d22c8_row7_col7" class="data row7 col7" >0.3110</td>
#     </tr>
#     <tr>
#       <th id="T_d22c8_level0_row8" class="row_heading level0 row8" >dummy</th>
#       <td id="T_d22c8_row8_col0" class="data row8 col0" >Dummy Regressor</td>
#       <td

# %%
best_model = compare_models([best_model_v1, best_model_v2, best_model_v3, best_model_v4, best_model_v5, best_model_v6])
# Out:
# <style type="text/css">
# #T_eb848 th {
#   text-align: left;
# }
# #T_eb848_row0_col0, #T_eb848_row1_col0, #T_eb848_row2_col0, #T_eb848_row3_col0, #T_eb848_row4_col0, #T_eb848_row4_col1, #T_eb848_row4_col2, #T_eb848_row4_col3, #T_eb848_row4_col4, #T_eb848_row4_col5, #T_eb848_row4_col6, #T_eb848_row5_col0, #T_eb848_row5_col1, #T_eb848_row5_col2, #T_eb848_row5_col3, #T_eb848_row5_col4, #T_eb848_row5_col5, #T_eb848_row5_col6 {
#   text-align: left;
# }
# #T_eb848_row0_col1, #T_eb848_row0_col2, #T_eb848_row0_col3, #T_eb848_row0_col4, #T_eb848_row0_col5, #T_eb848_row0_col6, #T_eb848_row1_col1, #T_eb848_row1_col2, #T_eb848_row1_col3, #T_eb848_row1_col4, #T_eb848_row1_col5, #T_eb848_row1_col6, #T_eb848_row2_col1, #T_eb848_row2_col2, #T_eb848_row2_col3, #T_eb848_row2_col4, #T_eb848_row2_col5, #T_eb848_row2_col6, #T_eb848_row3_col1, #T_eb848_row3_col2, #T_eb848_row3_col3, #T_eb848_row3_col4, #T_eb848_row3_col5, #T_eb848_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_eb848_row0_col7, #T_eb848_row1_col7, #T_eb848_row2_col7, #T_eb848_row3_col7, #T_eb848_row4_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_eb848_row5_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_eb848">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb848_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_eb848_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_eb848_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_eb848_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_eb848_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_eb848_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_eb848_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_eb848_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb848_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_eb848_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_eb848_row0_col1" class="data row0 col1" >10.8587</td>
#       <td id="T_eb848_row0_col2" class="data row0 col2" >348.7463</td>
#       <td id="T_eb848_row0_col3" class="data row0 col3" >18.5810</td>
#       <td id="T_eb848_row0_col4" class="data row0 col4" >0.9997</td>
#       <td id="T_eb848_row0_col5" class="data row0 col5" >0.0025</td>
#       <td id="T_eb848_row0_col6" class="data row0 col6" >0.0015</td>
#       <td id="T_eb848_row0_col7" class="data row0 col7" >0.7610</td>
#     </tr>
#     <tr>
#       <th id="T_eb848_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_eb848_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_eb848_row1_col1" class="data row1 col1" >10.8587</td>
#       <td id="T_eb848_row1_col2" class="data row1 col2" >348.7463</td>
#       <td id="T_eb848_row1_col3" class="data row1 col3" >18.5810</td>
#       <td id="T_eb848_row1_col4" class="data row1 col4" >0.9997</td>
#       <td id="T_eb848_row1_col5" class="data row1 col5" >0.0025</td>
#       <td id="T_eb848_row1_col6" class="data row1 col6" >0.0015</td>
#       <td id="T_eb848_row1_col7" class="data row1 col7" >0.7550</td>
#     </tr>
#     <tr>
#       <th id="T_eb848_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_eb848_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_eb848_row2_col1" class="data row2 col1" >10.8587</td>
#       <td id="T_eb848_row2_col2" class="data row2 col2" >348.7463</td>
#       <td id="T_eb848_row2_col3" class="data row2 col3" >18.5810</td>
#       <td id="T_eb848_row2_col4" class="data row2 col4" >0.9997</td>
#       <td id="T_eb848_row2_col5" class="data row2 col5" >0.0025</td>
#       <td id="T_eb848_row2_col6" class="data row2 col6" >0.0015</td>
#       <td id="T_eb848_row2_col7" class="data row2 col7" >0.7580</td>
#     </tr>
#     <tr>
#       <th id="T_eb848_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_eb848_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_eb848_row3_col1" class="data row3 col1" >10.8587</td>
#       <td id="T_eb848_row3_col2" class="data row3 col2" >348.7463</td>
#       <td id="T_eb848_row3_col3" class="data row3 col3" >18.5810</td>
#       <td id="T_eb848_row3_col4" class="data row3 col4" >0.9997</td>
#       <td id="T_eb848_row3_col5" class="data row3 col5" >0.0025</td>
#       <td id="T_eb848_row3_col6" class="data row3 col6" >0.0015</td>
#       <td id="T_eb848_row3_col7" class="data row3 col7" >0.7580</td>
#     </tr>
#     <tr>
#       <th id="T_eb848_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_eb848_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_eb848_row4_col1" class="data row4 col1" >15.6124</td>
#       <td id="T_eb848_row4_col2" class="data row4 col2" >711.5376</td>
#       <td id="T_eb848_row4_col3" class="data row4 col3" >26.6180</td>
#       <td id="T_eb848_row4_col4" class="data row4 col4" >0.9994</td>
#       <td id="T_eb848_row4_col5" class="data row4 col5" >0.0035</td>
#       <td id="T_eb848_row4_col6" class="data row4 col6" >0.0021</td>
#       <td id="T_eb848_row4_col7" class="data row4 col7" >1.4660</td>
#     </tr>
#     <tr>
#       <th id="T_eb848_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_eb848_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_eb848_row5_col1" class="data row5 col1" >18.8366</td>
#       <td id="T_eb848_row5_col2" class="data row5 col2" >1944.1457</td>
#       <td id="T_eb848_row5_col3" class="data row5 col3" >43.9002</td>
#       <td id="T_eb848_row5_col4" class="data row5 col4" >0.9983</td>
#       <td id="T_eb848_row5_col5" class="data row5 col5" >0.0057</td>
#       <td id="T_eb848_row5_col6" class="data row5 col6" >0.0025</td>
#       <td id="T_eb848_row5_col7" class="data row5 col7" >0.0760</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Wybieram najlepszy model z najmniejszym błędem

# %%
# Strojenie hiperparametrów
best_model_tuned = exp.tune_model(
    estimator=best_model,  # Wybrany model
    n_iter=50,            # Liczba iteracji dla Random Grid Search
    optimize='MAE'         # Metryka do optymalizacji
)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   10:26:21
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .      Extra Trees Regressor
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 50 candidates, totalling 500 fits

# %%
best_final_model = compare_models([best_model, best_model_tuned])

# %% [markdown]
# ## Porównanie oryginalnego modelu, oraz miodelu po strojeniu hiperparametrów wykazało że nie ma żadnej różnicy w podejściach.
# ### Możliwę że zwiększenie liczby iteracji by coś zmieniło, ale byłaby to marginalna zmiana

# %%
exp.predict_model(best_final_model)

# %% [markdown]
# Podgląd predykcji pozwala zrozumieć, co model przewidywał i na podstawie jakich danych:
#
# Cel Predykcji: Zmienna docelowa to prediction_label. Biorąc pod uwagę inne kolumny (5 km Czas Open, 10 km Czas Open, etc.), można ztwierdzić że model przewiduje czas biegu (np. półmaratonu/maratonu).
#
# Kluczowe Predyktory: Model wykorzystuje szereg cech związanych z bieganiem, takich jak:
#
# Czasy na krótszych dystansach (5 km Czas Open, 10 km Czas Open, 15 km Czas Open).
#
# Płeć, Kategoria wiekowa (M20, K20, M30).

# %%
plot_model(best_final_model, plot='feature')
plot_model(best_final_model, plot='error')
plot_model(best_final_model, plot='residuals')

# %%
# Trenowanie modelu na całym zbiorze danych
final_model = finalize_model(best_final_model)

# %%
# Zapis modelu lokalnie
final_model = finalize_model(best_model)
save_model(final_model, 'final_regression_pipeline')

# %%
s3.upload_file(
    Filename='final_regression_pipeline.pkl',
    Bucket=BUCKET_NAME,
    Key='Train_Model/final_regression_pipeline.pkl'
)

# %%
def predict_halfmarathon_time(wiek, plec, five_k_time_sec, model):
    """
    Funkcja do predykcji czasu ukończenia półmaratonu.

    Args:
        wiek (int): wiek biegacza
        plec (str): 'M' lub 'K'
        five_k_time_sec (int): czas 5 km w sekundach
        model: wytrenowany model pycaret

    Returns:
        str: czas w formacie H:M:S
    """
    # Dane wejściowe z wszystkimi kolumnami
    user_input = pd.DataFrame([{
        'Miejsce': 1.0,
        'Numer startowy': 1,
        'Imię': 'Test',
        'Nazwisko': 'User',
        'Kraj': 'POL',
        'Płeć': plec,
        'Płeć Miejsce': 1.0,
        'Kategoria wiekowa': 'M30' if plec == 'M' else 'K30',
        'Kategoria wiekowa Miejsce': 1.0,
        '5 km Czas': five_k_time_sec,
        '5 km Miejsce Open': 1.0,
        '10 km Czas': five_k_time_sec * 2,  # Przybliżenie
        '10 km Miejsce Open': 1.0,
        '15 km Czas': five_k_time_sec * 3,  # Przybliżenie
        '15 km Miejsce Open': 1.0,
        '20 km Czas': five_k_time_sec * 4,  # Przybliżenie
        '20 km Miejsce Open': 1.0,
        'Tempo Stabilność': 0.02,
        'Wiek': wiek
    }])

    # Predykcja
    prediction = predict_model(model, data=user_input)
    pred_seconds = int(round(prediction['prediction_label'][0]))

    # Konwersja na H:M:S
    pred_time_str = str(datetime.timedelta(seconds=pred_seconds))
    return pred_time_str

# Przykład użycia:
wiek_input = 42
plec_input = 'M'
czas_5km_input = 2000  # w sekundach

predykcja_czasu = predict_halfmarathon_time(wiek_input, plec_input, czas_5km_input, final_model)
print(f"Przewidywany czas ukończenia półmaratonu: {predykcja_czasu}")
